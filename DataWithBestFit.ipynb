# %%
import numpy as np
Polynomial = np.polynomial.Polynomial
#In this notebook I'm using the numpy.polynomial module to make a best fit 
import pylab 
#I imported this to help with creating the best fit

# %%
from matplotlib import pyplot as plt
#I used pyplot from matplotlib to form my graph



file = 'data.v3.txt'
#I entered the data that was given through a .txt file

plt.plot(filedat['x'], filedat['y'],'r-')
plt.plot(filedat['x'], filedat['y'],'bo')
plt.xlabel('x')
plt.ylabel('y')
plt.title('x-y plot')
#These rows put together the red and blue plot below
#The 'r-' indicates that the points are connected by red dashes/lines
#The 'bo' indicates that the points are blue filled in circles
#The next three lines are labels for the graph
new_x = filedat['x']
new_y = filedat['y']
#New variables are needed for calculations that Python will run
cmin, cmax = min(new_x), max(new_x)
#This tells the program to find the mins and maxs in the x and y direction for all these points
pfit, stats = Polynomial.fit(new_x, new_y, 1, full=True, window=(cmin, cmax),
                                                    domain=(cmin, cmax))
#This line of code creates the best fit and finds the average for every single point to the line in the middle
#It is a first order polynomial, and therefore the dimension is 1

pylab.plot(new_x, pfit(new_x), color='k')
pylab.show()
#The color is made to be black ('k') to differentiate from the plot
#pylab.show() allows the pylab actions to be viewed

#This is consisted of a lot of what I worked on f
